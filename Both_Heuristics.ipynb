# %%
import menu as RunMenu
import Rig_MCLP as rig
import SelectFile as file_select
import Constructive as constructive
import Constructive2 as constructive2
import LocalSearch as ls
import sys

# %%
# Run and get data for constructive from menu
option = RunMenu.menu()

# Execute based on menu
if option == 1:
    rig.runRIG()
    sys.exit()
elif option == 2:
    initial_data = file_select.GetCandidateAndDemand()
else:
    RunMenu.menu()
# Out:
# 1.- instance#31.txt
# Selected file: instance#31.txt

# %%
# Set data for constructive
candidate = initial_data[0]
demand = initial_data[1]
p = initial_data[2]
f = initial_data[3]
sf = initial_data[4]
r = initial_data[5]

# Run and get results from worst constructive
c_data = constructive.Constructive(candidate, demand, p, f, sf, r)
# Out:
# -- Initial Plot --
# -- Constructive Heuristic 1 --
# 22
# Selected sites with count of covered points: [[[97, 61], 2], [[16, 7], 3], [[1, 58], 1], [[91, 46], 2], [[86, 15], 1], [[0, 35], 2], [[30, 81], 5], [[56, 69], 2], [[74, 3], 2], [[59, 24], 2]]
# 0.22318243980407715

# %%
# Set data for local search
c_demand = c_data[0]
c_candidate = c_data[1]
c_of = c_data[2]
c_sf = c_data[3]
c_r = c_data[4]
c_title = c_data[5]
c_p = c_data[6]
c_selected_sites = c_data[7]

# Run local search with previous results
ls.LocalSearch(c_demand, c_candidate, c_of, c_sf, c_r, c_title, c_p, c_selected_sites)
# Out:
# -- Local Search Heuristic --
# [39, 85] covers point: [45, 80] , distance = 7.810249675906654
# [39, 85] covers point: [32, 83] , distance = 7.280109889280518
# [39, 85] covers point: [49, 85] , distance = 10.0
# [83, 55] covers point: [79, 64] , distance = 9.848857801796104
# [54, 94] covers point: [61, 95] , distance = 7.0710678118654755
# [54, 94] covers point: [57, 96] , distance = 3.605551275463989
# [54, 94] covers point: [60, 88] , distance = 8.48528137423857
# [57, 28] covers point: [64, 21] , distance = 9.899494936611665
# [57, 28] covers point: [51, 22] , distance = 8.48528137423857
# [70, 22] covers point: [70, 32] , distance = 10.0
# [70, 22] covers point: [75, 29] , distance = 8.602325267042627
# [44, 32] covers point: [43, 27] , distance = 5.0990195135927845
# [44, 32] covers point: [44, 42] , distance = 10.0
# [44, 32] covers point: [36, 37] , distance = 9.433981132056603
# [19, 71] covers point: [21, 68] , distance = 3.605551275463989
# [19, 71] covers point: [14, 73] , distance = 5.385164807134504
# [37, 82] covers point: [34, 76] , distance = 6.708203932499369
# [37, 82] covers point: [33, 74] , distance = 8.94427190999916
# 27
# New selected sites with count of covered points: [[[39, 85], 3], [[16, 7], 3], [[54, 94], 3], [[44, 32], 3], [[57, 28], 2], [[0, 35], 2], [[30, 81], 5], [[56, 69], 2], [[74, 3], 2], [[59, 24], 2]]
# 0.21358966827392578

# %%
# Run and get results from constructive
c_data = constructive2.Constructive(candidate, demand, p, f, sf, r)
# Out:
# -- Constructive Heuristic 2 --
# [30, 81] covers point: [26, 87] , distance = 7.211102550927978
# [30, 81] covers point: [34, 76] , distance = 6.4031242374328485
# [30, 81] covers point: [32, 83] , distance = 2.8284271247461903
# [30, 81] covers point: [25, 86] , distance = 7.0710678118654755
# [30, 81] covers point: [33, 74] , distance = 7.615773105863909
# [86, 15] covers point: [86, 10] , distance = 5.0
# [0, 35] covers point: [1, 38] , distance = 3.1622776601683795
# [0, 35] covers point: [8, 39] , distance = 8.94427190999916
# [1, 58] covers point: [4, 57] , distance = 3.1622776601683795
# [91, 46] covers point: [84, 41] , distance = 8.602325267042627
# [91, 46] covers point: [87, 40] , distance = 7.211102550927978
# [39, 85] covers point: [45, 80] , distance = 7.810249675906654
# [39, 85] covers point: [49, 85] , distance = 10.0
# [83, 55] covers point: [79, 64] , distance = 9.848857801796104
# [56, 69] covers point: [56, 63] , distance = 6.0
# [56, 69] covers point: [52, 66] , distance = 5.0
# [74, 3] covers point: [73, 6] , distance = 3.1622776601683795
# [74, 3] covers point: [71, 5] , distance = 3.605551275463989
# [97, 61] covers point: [94, 69] , distance = 8.54400374531753
# [97, 61] covers point: [99, 56] , distance = 5.385164807134504
# 20
# Selected sites with count of covered points: [[[30, 81], 5], [[86, 15], 1], [[0, 35], 2], [[1, 58], 1], [[91, 46], 2], [[39, 85], 2], [[83, 55], 1], [[56, 69], 2], [[74, 3], 2], [[97, 61], 2]]
# Running time:0.19939804077148438

# %%
# Set data for local search
c_demand = c_data[0]
c_candidate = c_data[1]
c_of = c_data[2]
c_sf = c_data[3]
c_r = c_data[4]
c_title = c_data[5]
c_p = c_data[6]
c_selected_sites = c_data[7]

# Run local search with previous results
ls.LocalSearch(c_demand, c_candidate, c_of, c_sf, c_r, c_title, c_p, c_selected_sites)
# Out:
# -- Local Search Heuristic --
# [16, 7] covers point: [9, 14] , distance = 9.899494936611665
# [16, 7] covers point: [15, 3] , distance = 4.123105625617661
# [16, 7] covers point: [23, 8] , distance = 7.0710678118654755
# [54, 94] covers point: [61, 95] , distance = 7.0710678118654755
# [54, 94] covers point: [57, 96] , distance = 3.605551275463989
# [54, 94] covers point: [60, 88] , distance = 8.48528137423857
# [43, 87] covers point: [45, 80] , distance = 7.280109889280518
# [43, 87] covers point: [49, 85] , distance = 6.324555320336759
# [59, 24] covers point: [64, 21] , distance = 5.830951894845301
# [59, 24] covers point: [51, 22] , distance = 8.246211251235321
# [70, 22] covers point: [70, 32] , distance = 10.0
# [70, 22] covers point: [75, 29] , distance = 8.602325267042627
# [44, 32] covers point: [43, 27] , distance = 5.0990195135927845
# [44, 32] covers point: [44, 42] , distance = 10.0
# [44, 32] covers point: [36, 37] , distance = 9.433981132056603
# [19, 71] covers point: [21, 68] , distance = 3.605551275463989
# [19, 71] covers point: [14, 73] , distance = 5.385164807134504
# [37, 82] covers point: [34, 76] , distance = 6.708203932499369
# [37, 82] covers point: [32, 83] , distance = 5.0990195135927845
# [37, 82] covers point: [33, 74] , distance = 8.94427190999916
# 27
# New selected sites with count of covered points: [[[30, 81], 5], [[16, 7], 3], [[54, 94], 3], [[44, 32], 3], [[37, 82], 3], [[39, 85], 2], [[59, 24], 2], [[56, 69], 2], [[74, 3], 2], [[97, 61], 2]]
# 0.21253490447998047
